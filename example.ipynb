# %% [markdown]
# <a href="https://colab.research.google.com/github/TYAGAGerson/TYAGAGerson/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# definisi fungsi:

# %%
def luasTrapesium(a1,a2,t):
    return (a1+a2)/2*t

# %% [markdown]
# panggil fungsi:

# %%
luasTrapesium(5,7,2)
# Out:
# 12.0

# %% [markdown]
# jadi gitu
